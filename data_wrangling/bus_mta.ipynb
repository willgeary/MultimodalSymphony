# %% [markdown]
# # Visualizing NYC Bus Timetables

# %% [markdown]
# Data source:
#
# http://web.mta.info/developers/data/nyct/bus/google_transit_bronx.zip
#
# http://web.mta.info/developers/data/nyct/bus/google_transit_brooklyn.zip
#
# http://web.mta.info/developers/data/nyct/bus/google_transit_manhattan.zip
#
# http://web.mta.info/developers/data/nyct/bus/google_transit_queens.zip
#
# http://web.mta.info/developers/data/nyct/bus/google_transit_staten_island.zip

# %% [markdown]
# Import libraries.

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# # Brooklyn

# %% [markdown]
# ### Load GTFS data

# %%
agency = pd.read_csv('gtfs/brooklyn/agency.txt')
calendar_dates = pd.read_csv('gtfs/brooklyn/calendar_dates.txt')
calendar = pd.read_csv('gtfs/brooklyn/calendar.txt')
routes = pd.read_csv('gtfs/brooklyn/routes.txt')
shapes = pd.read_csv('gtfs/brooklyn/shapes.txt')
stop_times = pd.read_csv('gtfs/brooklyn/stop_times.txt')
stops = pd.read_csv('gtfs/brooklyn/stops.txt')
trips = pd.read_csv('gtfs/brooklyn/trips.txt')

# %% [markdown]
# ### Preview the data

# %%
agency.head()
# Out:
#   agency_id                agency_name            agency_url  \
# 0  MTA NYCT  MTA New York City Transit   http://www.mta.info
#
#     agency_timezone agency_lang  agency_phone
# 0  America/New_York          en  718-330-1234

# %%
calendar_dates.head()
# Out:
#            service_id      date  exception_type
# 0  EN_A7-Weekday-SDon  20170116               2
# 1  EN_A7-Weekday-SDon  20170220               2
# 2  EN_A7-Weekday-SDon  20170221               2
# 3  EN_A7-Weekday-SDon  20170222               2
# 4  EN_A7-Weekday-SDon  20170223               2

# %%
calendar.head()
# Out:
#            service_id  monday  tuesday  wednesday  thursday  friday  saturday  \
# 0        EN_A7-Sunday       0        0          0         0       0         0
# 1  EN_A7-Weekday-SDon       1        1          1         1       1         0
# 2      EN_A7-Saturday       0        0          0         0       0         1
# 3       EN_H7-Weekday       1        1          1         1       1         0
# 4       EN_A7-Weekday       1        1          1         1       1         0
#
#    sunday  start_date  end_date
# 0       1    20170108  20170326
# 1       0    20170109  20170331
# 2       0    20170114  20170401
# 3       0    20170116  20170116
# 4       0    20170221  20170224

# %%
routes.head(2)
# Out:
#   route_id agency_id route_short_name              route_long_name  \
# 0       B1  MTA NYCT               B1  Bay Ridge - Manhattan Beach
# 1      B11  MTA NYCT              B11        Sunset Park - Midwood
#
#                       route_desc  route_type  \
# 0       via 86th St / Ocean Pkwy           3
# 1  via 49th & 50th St / Avenue J           3
#
#                                            route_url route_color  \
# 0  http://web.mta.info/nyct/bus/schedule/bkln/b00...      00AEEF
# 1  http://web.mta.info/nyct/bus/schedule/bkln/b01...      006CB7
#
#   route_text_color
# 0           FFFFFF
# 1           FFFFFF

# %%
shapes.head(2)
# Out:
#   shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence
# 0   B10163     40.621900    -74.028521              10001
# 1   B10163     40.621997    -74.028681              10002

# %%
stop_times.head()
# Out:
#                       trip_id arrival_time departure_time  stop_id  \
# 0  EN_H7-Weekday-008100_B12_1     01:21:00       01:21:00   801177
# 1  EN_H7-Weekday-008100_B12_1     01:22:36       01:22:36   301386
# 2  EN_H7-Weekday-008100_B12_1     01:23:07       01:23:07   301387
# 3  EN_H7-Weekday-008100_B12_1     01:24:01       01:24:01   301388
# 4  EN_H7-Weekday-008100_B12_1     01:24:18       01:24:18   301389
#
#    stop_sequence  pickup_type  drop_off_type
# 0              1            0              0
# 1              2            0              0
# 2              3            0              0
# 3              4            0              0
# 4              5            0              0

# %%
stops.head()
# Out:
#    stop_id                 stop_name  stop_desc   stop_lat   stop_lon  \
# 0   300000  ORIENTAL BL/MACKENZIE ST        NaN  40.578251 -73.939743
# 1   300002    ORIENTAL BL/JAFFRAY ST        NaN  40.578068 -73.943031
# 2   300003   ORIENTAL BL/HASTINGS ST        NaN  40.577961 -73.944664
# 3   300004   ORIENTAL BL/FALMOUTH ST        NaN  40.577721 -73.946205
# 4   300006      ORIENTAL BL/DOVER ST        NaN  40.577354 -73.949554
#
#    zone_id  stop_url  location_type  parent_station
# 0      NaN       NaN              0             NaN
# 1      NaN       NaN              0             NaN
# 2      NaN       NaN              0             NaN
# 3      NaN       NaN              0             NaN
# 4      NaN       NaN              0             NaN

# %%
trips.head()
# Out:
#   route_id     service_id                     trip_id          trip_headsign  \
# 0      B12  EN_H7-Weekday  EN_H7-Weekday-008100_B12_1  LEFFRTS GDNS OCEAN AV
# 1      B12  EN_H7-Weekday  EN_H7-Weekday-011000_B12_1     EAST NY ALABAMA AV
# 2      B12  EN_H7-Weekday  EN_H7-Weekday-016100_B12_1  LEFFRTS GDNS OCEAN AV
# 3      B12  EN_H7-Weekday  EN_H7-Weekday-019000_B12_1     EAST NY ALABAMA AV
# 4      B12  EN_H7-Weekday  EN_H7-Weekday-012100_B12_2  LEFFRTS GDNS OCEAN AV
#
#    direction_id shape_id
# 0             1  B120114
# 1             0  B120113
# 2             1  B120114
# 3             0  B120113
# 4             1  B120114

# %% [markdown]
# ### Merge calendar, service_id and trip_id information

# %% [markdown]
# Join calendar and trips on service_id = trip_id.

# %%
service_trip_id = pd.merge(calendar[['service_id']],trips[['service_id', 'trip_id']])
service_trip_id.head()
# Out:
#      service_id                      trip_id
# 0  EN_A7-Sunday  EN_A7-Sunday-060000_B84_201
# 1  EN_A7-Sunday  EN_A7-Sunday-063000_B65_101
# 2  EN_A7-Sunday  EN_A7-Sunday-066000_B84_201
# 3  EN_A7-Sunday  EN_A7-Sunday-069000_B65_101
# 4  EN_A7-Sunday  EN_A7-Sunday-072000_B84_201

# %% [markdown]
# Join calendar with trip_id.

# %%
calendar = pd.merge(calendar,service_trip_id)
calendar.head()
# Out:
#      service_id  monday  tuesday  wednesday  thursday  friday  saturday  \
# 0  EN_A7-Sunday       0        0          0         0       0         0
# 1  EN_A7-Sunday       0        0          0         0       0         0
# 2  EN_A7-Sunday       0        0          0         0       0         0
# 3  EN_A7-Sunday       0        0          0         0       0         0
# 4  EN_A7-Sunday       0        0          0         0       0         0
#
#    sunday  start_date  end_date                      trip_id
# 0       1    20170108  20170326  EN_A7-Sunday-060000_B84_201
# 1       1    20170108  20170326  EN_A7-Sunday-063000_B65_101
# 2       1    20170108  20170326  EN_A7-Sunday-066000_B84_201
# 3       1    20170108  20170326  EN_A7-Sunday-069000_B65_101
# 4       1    20170108  20170326  EN_A7-Sunday-072000_B84_201

# %% [markdown]
# Here's what the stop_times table looks like:

# %%
stop_times.head()
# Out:
#                       trip_id arrival_time departure_time  stop_id  \
# 0  EN_H7-Weekday-008100_B12_1     01:21:00       01:21:00   801177
# 1  EN_H7-Weekday-008100_B12_1     01:22:36       01:22:36   301386
# 2  EN_H7-Weekday-008100_B12_1     01:23:07       01:23:07   301387
# 3  EN_H7-Weekday-008100_B12_1     01:24:01       01:24:01   301388
# 4  EN_H7-Weekday-008100_B12_1     01:24:18       01:24:18   301389
#
#    stop_sequence  pickup_type  drop_off_type
# 0              1            0              0
# 1              2            0              0
# 2              3            0              0
# 3              4            0              0
# 4              5            0              0

# %% [markdown]
# ### Add abritrary arrival and departure dates to timetables

# %% [markdown]
# Define a function to add arrival dates to stop_times tables. We will use 1/5/15 as the start date because that is the date we are currently using to visualize taxi trips. This code deals with arrival times > 24 hours and converts them to 1/6/15.

# %%
arbitrary_dates = ['1/5/2015', '1/6/2015']

# %%
def add_arrival_date(df, dates = arbitrary_dates):
    df = df.copy()
    arrival_date = []
    arrival_time = []

    for i in df['arrival_time']:
        hour = i[:i.find(':')]
        minute = i[i.find(':')+1:i.find(':',4)]
        second = i[i.find(':',5)+1:]
        
        if int(hour) < 24:
            arrival_date.append(dates[0])
            arrival_time.append(i)
        elif 24 <= int(hour) < 48:
            arrival_date.append(dates[1])
            hour = int(hour) - 24
            arrival_time.append(str(hour)+":"+minute+":"+second)
        else:
            arrival_date.append('NA')
            
    df['arrival_date'] = arrival_date
    df['arrival_time'] = arrival_time
    return df

# %% [markdown]
# Define a function to add departure dates to stop_times tables. We will use 1/5/15 as the start date because that is the date we are currently using to visualize taxi trips. This code deals with departure times > 24 hours and converts them to 1/6/15.

# %%
def add_departure_date(df, dates = arbitrary_dates):
    df = df.copy()
    departure_date = []
    departure_time = []

    for i in df['departure_time']:
        hour = i[:i.find(':')]
        minute = i[i.find(':')+1:i.find(':',4)]
        second = i[i.find(':',5)+1:]
        
        if int(hour) < 24:
            departure_date.append(dates[0])
            departure_time.append(i)
        elif 24 <= int(hour) < 48:
            departure_date.append(dates[1])
            hour = int(hour) - 24
            departure_time.append(str(hour)+":"+minute+":"+second)
        else:
            departure_date.append('NA')
            
    df['departure_date'] = departure_date
    df['departure_time'] = departure_time
    return df

# %% [markdown]
# ### Get timetables for each day of the week

# %%
monday = calendar[calendar['monday'] == 1]
tuesday = calendar[calendar['tuesday'] == 1]
wednesday = calendar[calendar['wednesday'] == 1]
thursday = calendar[calendar['thursday'] == 1]
friday = calendar[calendar['friday'] == 1]
saturday = calendar[calendar['saturday'] == 1]
sunday = calendar[calendar['sunday'] == 1]

# %% [markdown]
# Store the results here:

# %%
triplist = []

# %% [markdown]
# ### Monday

# %%
monday.head(2)
# Out:
#               service_id  monday  tuesday  wednesday  thursday  friday  \
# 1955  EN_A7-Weekday-SDon       1        1          1         1       1
# 1956  EN_A7-Weekday-SDon       1        1          1         1       1
#
#       saturday  sunday  start_date  end_date  \
# 1955         0       0    20170109  20170331
# 1956         0       0    20170109  20170331
#
#                                 trip_id
# 1955  EN_A7-Weekday-SDon-007000_Q24_401
# 1956  EN_A7-Weekday-SDon-012000_Q24_401

# %%
monday_trips = monday['trip_id']
print "There are ", len(monday_trips), "trips on Monday"
monday_trips.head()
# Out:
# There are  39306 trips on Monday
# 1955    EN_A7-Weekday-SDon-007000_Q24_401
# 1956    EN_A7-Weekday-SDon-012000_Q24_401
# 1957    EN_A7-Weekday-SDon-016000_Q24_401
# 1958    EN_A7-Weekday-SDon-020000_Q24_401
# 1959    EN_A7-Weekday-SDon-024500_Q24_401
# Name: trip_id, dtype: object

# %%
for i in monday_trips:
    df = stop_times[stop_times['trip_id'] == i]
    df = add_arrival_date(df, dates = arbitrary_dates)
    df = add_departure_date(df, dates = arbitrary_dates)
    
    df['arrival_datetime'] = pd.to_datetime(df['arrival_date'] + ' ' + df['arrival_time'])
    df['departure_datetime'] = pd.to_datetime(df['departure_date'] + ' ' + df['departure_time'])


    # join df with stops
    df = pd.merge(df, stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']],left_on='stop_id', right_on='stop_id')

    # join df with trips to get direction id
    df = pd.merge(df, trips[['trip_id', 'direction_id', 'route_id']], left_on='trip_id', right_on='trip_id', how='left')

    # join df with routes to get route id
    df = pd.merge(df, routes[['route_id', 'route_long_name']], left_on='route_id', right_on='route_id', how='left')

    # make a new dataframe called legs
    legs = pd.DataFrame()
    legs['starttime'] = df['departure_datetime']
    legs['stoptime'] = df['arrival_datetime'].shift(-1).fillna(method='ffill')
    legs['tripduration'] = (legs['stoptime'] - legs['starttime'])/np.timedelta64(1, 's')
    legs['tripduration'] = [int(x) for x in legs['tripduration']]
    legs['start station id'] = df['stop_id']
    legs['start station name'] = df['stop_name']
    legs['start station latitude'] = df['stop_lat']
    legs['start station longitude'] = df['stop_lon']
    legs['end station id'] = legs['start station id'].shift(-1).fillna(method='ffill')
    legs['end station name'] = legs['start station name'].shift(-1).fillna(method='ffill')
    legs['end station latitude'] = legs['start station latitude'].shift(-1).fillna(method='ffill')
    legs['end station longitude'] = legs['start station longitude'].shift(-1).fillna(method='ffill')
    legs['route_id'] = 1 # arbitrary
    legs['direction'] = df['direction_id']
    legs['trainName'] = df['route_long_name']

    triplist.append(legs)

# %%
triplist[1]
# Out:
#              starttime            stoptime  tripduration  start station id  \
# 0  2015-01-05 02:00:00 2015-01-05 02:00:34            34            504384
# 1  2015-01-05 02:00:34 2015-01-05 02:01:38            64            503185
# 2  2015-01-05 02:01:38 2015-01-05 02:02:44            66            504535
# 3  2015-01-05 02:02:44 2015-01-05 02:03:33            49            503953
# 4  2015-01-05 02:03:33 2015-01-05 02:04:40            67            503932
# 5  2015-01-05 02:04:40 2015-01-05 02:06:00            80            502145
# 6  2015-01-05 02:06:00 2015-01-05 02:06:58            58            503184
# 7  2015-01-05 02:06:58 2015-01-05 02:08:00            62            504198
# 8  2015-01-05 02:08:00 2015-01-05 02:08:27            27            504199
# 9  2015-01-05 02:08:27 2015-01-05 02:09:06            39            504293
# 10 2015-01-05 02:09:06 2015-01-05 02:09:56            50            504080
# 11 2015-01-05 02:09:56 2015-01-05 02:10:37            41            503415
# 12 2015-01-05 02:10:37 2015-01-05 02:11:00            23            503416
# 13 2015-01-05 02:11:00 2015-01-05 02:11:45            45            503417
# 14 2015-01-05 02:11:45 2015-01-05 02:12:22            37            503418
# 15 2015-01-05 02:12:22 2015-01-05 02:13:00            38            503419
# 16 2015-01-05 02:13:00 2015-01-05 02:13:19            19            503420
# 17 2015-01-05 02:13:19 2015-01-05 02:13:44            25            503421
# 18 2015-01-05 02:13:44 2015-01-05 02:14:12            28            503422
# 19 2015-01-05 02:14:12 2015-01-05 02:14:39            27            503423
# 20 2015-01-05 02:14:39 2015-01-05 02:15:08            29            503424
# 21 2015-01-05 02:15:08 2015-01-05 02:15:36            28            503426
# 22 2015-01-05 02:15:36 2015-01-05 02:16:00            24            503427
# 23 2015-01-05 02:16:00 2015-01-05 02:16:32            32            503428
# 24 2015-01-05 02:16:32 2015-01-05 02:17:13            41            503429
# 25 2015-01-05 02:17:13 2015-01-05 02:17:44            31            503430
# 26 2015-01-05 02:17:44 2015-01-05 02:18:08            24            503431
# 27 2015-01-05 02:18:08 2015-01-05 02:18:42            34            503432
# 28 2015-01-05 02:18:42 2015-01-05 02:19:00            18            503433
# 29 2015-01-05 02:19:00 2015-01-05 02:19:13            13            503434
# 30 2015-01-05 02:19:13 2015-01-05 02:19:44            31            503435
# 31 2015-01-05 02:19:44 2015-01-05 02:20:07            23            503436
# 32 2015-01-05 02:20:07 2015-01-05 02:20:29            22            503437
# 33 2015-01-05 02:20:29 2015-01-05 02:21:04            35            503438
# 34 2015-01-05 02:21:04 2015-01-05 02:21:23            19            503439
# 35 2015-01-05 02:21:23 2015-01-05 02:21:45            22            503440
# 36 2015-01-05 02:21:45 2015-01-05 02:22:04            19            503441
# 37 2015-01-05 02:22:04 2015-01-05 02:22:18            14            503442
# 38 2015-01-05 02:22:18 2015-01-05 02:22:36            18            503443
# 39 2015-01-05 02:22:36 2015-01-05 02:23:15            39            308162
# 40 2015-01-05 02:23:15 2015-01-05 02:23:32            17            304624
# 41 2015-01-05 02:23:32 2015-01-05 02:24:00            28            304625
# 42 2015-01-05 02:24:00 2015-01-05 02:24:31            31            306362
# 43 2015-01-05 02:24:31 2015-01-05 02:25:10            39            308161
# 44 2015-01-05 02:25:10 2015-01-05 02:25:53            43            304628
# 45 2015-01-05 02:25:53 2015-01-05 02:26:30            37            304629
# 46 2015-01-05 02:26:30 2015-01-05 02:27:15            45            304630
# 47 2015-01-05 02:27:15 2015-01-05 02:27:47            32            304632
# 48 2015-01-05 02:27:47 2015-01-05 02:28:08            21            304633
# 49 2015-01-05 02:28:08 2015-01-05 02:28:45            37            304634
# 50 2015-01-05 02:28:45 2015-01-05 02:29:16            31            304635
# 51 2015-01-05 02:29:16 2015-01-05 02:29:47            31            304636
# 52 2015-01-05 02:29:47 2015-01-05 02:30:47            60            307859
# 53 2015-01-05 02:30:47 2015-01-05 02:31:20            33            307704
# 54 2015-01-05 02:31:20 2015-01-05 02:32:00            40            301384
# 55 2015-01-05 02:32:00 2015-01-05 02:33:00            60            308439
# 56 2015-01-05 02:33:00 2015-01-05 02:33:00             0            801063
#
#               start station name  start station latitude  \
# 0              JAMAICA AV/170 ST               40.707287
# 1              JAMAICA AV/168 PL               40.706787
# 2              JAMAICA AV/165 ST               40.705578
# 3              JAMAICA AV/162 ST               40.704224
# 4          JAMAICA AV/PARSONS BL               40.703278
# 5              JAMAICA AV/150 ST               40.702229
# 6              JAMAICA AV/146 ST               40.701828
# 7              JAMAICA AV/144 ST               40.702312
# 8           JAMAICA AV/QUEENS BL               40.702587
# 9              JAMAICA AV/138 ST               40.702545
# 10    JAMAICA AV/METROPOLITAN AV               40.702457
# 11             JAMAICA AV/132 ST               40.702126
# 12             JAMAICA AV/130 ST               40.701694
# 13             JAMAICA AV/127 ST               40.701378
# 14             JAMAICA AV/124 ST               40.700832
# 15             JAMAICA AV/122 ST               40.700497
# 16        JAMAICA AV/LEFFERTS BL               40.700092
# 17             JAMAICA AV/118 ST               40.699757
# 18             JAMAICA AV/116 ST               40.699024
# 19             JAMAICA AV/114 ST               40.698143
# 20             JAMAICA AV/112 ST               40.697243
# 21             JAMAICA AV/110 ST               40.696224
# 22             JAMAICA AV/108 ST               40.695530
# 23             JAMAICA AV/106 ST               40.695301
# 24             JAMAICA AV/104 ST               40.695244
# 25             JAMAICA AV/102 ST               40.695175
# 26              JAMAICA AV/98 ST               40.694847
# 27              JAMAICA AV/96 ST               40.694576
# 28              JAMAICA AV/94 ST               40.694157
# 29       JAMAICA AV/WOODHAVEN BL               40.693775
# 30  JAMAICA AV/WOODHAVEN BL WEST               40.693485
# 31              JAMAICA AV/90 ST               40.692825
# 32              JAMAICA AV/88 ST               40.692703
# 33              JAMAICA AV/86 ST               40.692604
# 34          JAMAICA AV/FOREST PY               40.692318
# 35              JAMAICA AV/80 ST               40.692097
# 36              JAMAICA AV/78 ST               40.691818
# 37              JAMAICA AV/76 ST               40.691559
# 38          JAMAICA AV/DEXTER CT               40.691391
# 39          JAMAICA AV/ELDERT LA               40.691170
# 40         JAMAICA AV/LINCOLN AV               40.690456
# 41         JAMAICA AV/HEMLOCK ST               40.689999
# 42        JAMAICA AV/CRESCENT ST               40.689159
# 43   JAMAICA AV/CYPRESS HILLS ST               40.688393
# 44        JAMAICA AV/RICHMOND ST               40.687332
# 45         JAMAICA AV/NORWOOD AV               40.686150
# 46        JAMAICA AV/HIGHLAND BL               40.685192
# 47         JAMAICA AV/LINWOOD ST               40.684025
# 48       JAMAICA AV/CLEVELAND ST               40.683201
# 49         JAMAICA AV/WARWICK ST               40.682648
# 50          JAMAICA AV/BARBEY ST               40.681686
# 51         JAMAICA AV/HENDRIX ST               40.680847
# 52          JAMAICA AV/MILLER AV               40.680054
# 53      JAMAICA AV/MARGINAL ST E               40.678524
# 54         JAMAICA AV/FANCHON PL               40.677662
# 55        JAMAICA AV/HERKIMER ST               40.677433
# 56     VAN SINDEREN AV/FULTON ST               40.678608
#
#     start station longitude  end station id              end station name  \
# 0                -73.789581        503185.0             JAMAICA AV/168 PL
# 1                -73.791458        504535.0             JAMAICA AV/165 ST
# 2                -73.794777        503953.0             JAMAICA AV/162 ST
# 3                -73.798172        503932.0         JAMAICA AV/PARSONS BL
# 4                -73.800682        502145.0             JAMAICA AV/150 ST
# 5                -73.804329        503184.0             JAMAICA AV/146 ST
# 6                -73.808846        504198.0             JAMAICA AV/144 ST
# 7                -73.811432        504199.0          JAMAICA AV/QUEENS BL
# 8                -73.814247        504293.0             JAMAICA AV/138 ST
# 9                -73.815773        504080.0    JAMAICA AV/METROPOLITAN AV
# 10               -73.817993        503415.0             JAMAICA AV/132 ST
# 11               -73.820801        503416.0             JAMAICA AV/130 ST
# 12               -73.823029        503417.0             JAMAICA AV/127 ST
# 13               -73.824287        503418.0             JAMAICA AV/124 ST
# 14               -73.826736        503419.0             JAMAICA AV/122 ST
# 15               -73.828743        503420.0        JAMAICA AV/LEFFERTS BL
# 16               -73.830841        503421.0             JAMAICA AV/118 ST
# 17               -73.832085        503422.0             JAMAICA AV/116 ST
# 18               -73.833611        503423.0             JAMAICA AV/114 ST
# 19               -73.835197        503424.0             JAMAICA AV/112 ST
# 20               -73.836731        503426.0             JAMAICA AV/110 ST
# 21               -73.838234        503427.0             JAMAICA AV/108 ST
# 22               -73.839897        503428.0             JAMAICA AV/106 ST
# 23               -73.841583        503429.0             JAMAICA AV/104 ST
# 24               -73.843422        503430.0             JAMAICA AV/102 ST
# 25               -73.845863        503431.0              JAMAICA AV/98 ST
# 26               -73.847656        503432.0              JAMAICA AV/96 ST
# 27               -73.849052        503433.0              JAMAICA AV/94 ST
# 28               -73.850960        503434.0       JAMAICA AV/WOODHAVEN BL
# 29               -73.851913        503435.0  JAMAICA AV/WOODHAVEN BL WEST
# 30               -73.852829        503436.0              JAMAICA AV/90 ST
# 31               -73.855095        503437.0              JAMAICA AV/88 ST
# 32               -73.856903        503438.0              JAMAICA AV/86 ST
# 33               -73.858620        503439.0          JAMAICA AV/FOREST PY
# 34               -73.861336        503440.0              JAMAICA AV/80 ST
# 35               -73.862854        503441.0              JAMAICA AV/78 ST
# 36               -73.864487        503442.0              JAMAICA AV/76 ST
# 37               -73.866013        503443.0          JAMAICA AV/DEXTER CT
# 38               -73.867096        308162.0          JAMAICA AV/ELDERT LA
# 39               -73.868484        304624.0         JAMAICA AV/LINCOLN AV
# 40               -73.871338        304625.0         JAMAICA AV/HEMLOCK ST
# 41               -73.872581        306362.0        JAMAICA AV/CRESCENT ST
# 42               -73.874504        308161.0   JAMAICA AV/CYPRESS HILLS ST
# 43               -73.876205        304628.0        JAMAICA AV/RICHMOND ST
# 44               -73.878334        304629.0         JAMAICA AV/NORWOOD AV
# 45               -73.880684        304630.0        JAMAICA AV/HIGHLAND BL
# 46               -73.882721        304632.0         JAMAICA AV/LINWOOD ST
# 47               -73.885216        304633.0       JAMAICA AV/CLEVELAND ST
# 48               -73.886963        304634.0         JAMAICA AV/WARWICK ST
# 49               -73.888138        304635.0          JAMAICA AV/BARBEY ST
# 50               -73.890152        304636.0         JAMAICA AV/HENDRIX ST
# 51               -73.891899        307859.0          JAMAICA AV/MILLER AV
# 52               -73.893555        307704.0      JAMAICA AV/MARGINAL ST E
# 53               -73.896904        301384.0         JAMAICA AV/FANCHON PL
# 54               -73.898727        308439.0        JAMAICA AV/HERKIMER ST
# 55               -73.900803        801063.0     VAN SINDEREN AV/FULTON ST
# 56               -73.903664        801063.0     VAN SINDEREN AV/FULTON ST
#
#     end station latitude  end station longitude  route_id  direction  \
# 0              40.706787             -73.791458         1          1
# 1              40.705578             -73.794777         1          1
# 2              40.704224             -73.798172         1          1
# 3              40.703278             -73.800682         1          1
# 4              40.702229             -73.804329         1          1
# 5              40.701828             -73.808846         1          1
# 6              40.702312             -73.811432         1          1
# 7              40.702587             -73.814247         1          1
# 8              40.702545             -73.815773         1          1
# 9              40.702457             -73.817993         1          1
# 10             40.702126             -73.820801         1          1
# 11             40.701694             -73.823029         1          1
# 12             40.701378             -73.824287         1          1
# 13             40.700832             -73.826736         1          1
# 14             40.700497             -73.828743         1          1
# 15             40.700092             -73.830841         1          1
# 16             40.699757             -73.832085         1          1
# 17             40.699024             -73.833611         1          1
# 18             40.698143             -73.835197         1          1
# 19             40.697243             -73.836731         1          1
# 20             40.696224             -73.838234         1          1
# 21             40.695530             -73.839897         1          1
# 22             40.695301             -73.841583         1          1
# 23             40.695244             -73.843422         1          1
# 24             40.695175             -73.845863         1          1
# 25             40.694847             -73.847656         1          1
# 26             40.694576             -73.849052         1          1
# 27             40.694157             -73.850960         1          1
# 28             40.693775             -73.851913         1          1
# 29             40.693485             -73.852829         1          1
# 30             40.692825             -73.855095         1          1
# 31             40.692703             -73.856903         1          1
# 32             40.692604             -73.858620         1          1
# 33             40.692318             -73.861336         1          1
# 34             40.692097             -73.862854         1          1
# 35             40.691818             -73.864487         1          1
# 36             40.691559             -73.866013         1          1
# 37             40.691391             -73.867096         1          1
# 38             40.691170             -73.868484         1          1
# 39             40.690456             -73.871338         1          1
# 40             40.689999             -73.872581         1          1
# 41             40.689159             -73.874504         1          1
# 42             40.688393             -73.876205         1          1
# 43             40.687332             -73.878334         1          1
# 44             40.686150             -73.880684         1          1
# 45             40.685192             -73.882721         1          1
# 46             40.684025             -73.885216         1          1
# 47             40.683201             -73.886963         1          1
# 48             40.682648             -73.888138         1          1
# 49             40.681686             -73.890152         1          1
# 50             40.680847             -73.891899         1          1
# 51             40.680054             -73.893555         1          1
# 52             40.678524             -73.896904         1          1
# 53             40.677662             -73.898727         1          1
# 54             40.677433             -73.900803         1          1
# 55             40.678608             -73.903664         1          1
# 56             40.678608             -73.903664         1          1
#
#                       trainName
# 0   Broadway Junction - Jamaica
# 1   Broadway Junction - Jamaica
# 2   Broadway Junction - Jamaica
# 3   Broadway Junction - Jamaica
# 4   Broadway Junction - Jamaica
# 5   Broadway Junction - Jamaica
# 6   Broadway Junction - Jamaica
# 7   Broadway Junction - Jamaica
# 8   Broadway Junction - Jamaica
# 9   Broadway Junction - Jamaica
# 10  Broadway Junction - Jamaica
# 11  Broadway Junction - Jamaica
# 12  Broadway Junction - Jamaica
# 13  Broadway Junction - Jamaica
# 14  Broadway Junction - Jamaica
# 15  Broadway Junction - Jamaica
# 16  Broadway Junction - Jamaica
# 17  Broadway Junction - Jamaica
# 18  Broadway Junction - Jamaica
# 19  Broadway Junction - Jamaica
# 20  Broadway Junction - Jamaica
# 21  Broadway Junction - Jamaica
# 22  Broadway Junction - Jamaica
# 23  Broadway Junction - Jamaica
# 24  Broadway Junction - Jamaica
# 25  Broadway Junction - Jamaica
# 26  Broadway Junction - Jamaica
# 27  Broadway Junction - Jamaica
# 28  Broadway Junction - Jamaica
# 29  Broadway Junction - Jamaica
# 30  Broadway Junction - Jamaica
# 31  Broadway Junction - Jamaica
# 32  Broadway Junction - Jamaica
# 33  Broadway Junction - Jamaica
# 34  Broadway Junction - Jamaica
# 35  Broadway Junction - Jamaica
# 36  Broadway Junction - Jamaica
# 37  Broadway Junction - Jamaica
# 38  Broadway Junction - Jamaica
# 39  Broadway Junction - Jamaica
# 40  Broadway Junction - Jamaica
# 41  Broadway Junction - Jamaica
# 42  Broadway Junction - Jamaica
# 43  Broadway Junction - Jamaica
# 44  Broadway Junction - Jamaica
# 45  Broadway Junction - Jamaica
# 46  Broadway Junction - Jamaica
# 47  Broadway Junction - Jamaica
# 48  Broadway Junction - Jamaica
# 49  Broadway Junction - Jamaica
# 50  Broadway Junction - Jamaica
# 51  Broadway Junction - Jamaica
# 52  Broadway Junction - Jamaica
# 53  Broadway Junction - Jamaica
# 54  Broadway Junction - Jamaica
# 55  Broadway Junction - Jamaica
# 56  Broadway Junction - Jamaica

# %% [markdown]
# Concatenate the list of dataframes:

# %%
data = pd.concat(triplist)

# %%
len(data)

# %%
data.head(2)

# %%
data.tail(2)

# %%
data.to_csv('brooklyn_monday_test.csv')

# %% [markdown]
# # Queens

# %% [markdown]
# ### Load GTFS data

# %%
agency = pd.read_csv('gtfs/queens/agency.txt')
calendar_dates = pd.read_csv('gtfs/queens/calendar_dates.txt')
calendar = pd.read_csv('gtfs/queens/calendar.txt')
routes = pd.read_csv('gtfs/queens/routes.txt')
shapes = pd.read_csv('gtfs/queens/shapes.txt')
stop_times = pd.read_csv('gtfs/queens/stop_times.txt')
stops = pd.read_csv('gtfs/queens/stops.txt')
trips = pd.read_csv('gtfs/queens/trips.txt')

# %%
service_trip_id = pd.merge(calendar[['service_id']],trips[['service_id', 'trip_id']])
calendar = pd.merge(calendar,service_trip_id)
arbitrary_dates = ['1/5/2015', '1/6/2015']

# %% [markdown]
# ### Monday

# %%
monday = calendar[calendar['monday'] == 1]
tuesday = calendar[calendar['tuesday'] == 1]
wednesday = calendar[calendar['wednesday'] == 1]
thursday = calendar[calendar['thursday'] == 1]
friday = calendar[calendar['friday'] == 1]
saturday = calendar[calendar['saturday'] == 1]
sunday = calendar[calendar['sunday'] == 1]

# %%
triplist = []

# %%
monday_trips = monday['trip_id']
print "There are ", len(monday_trips), "trips on Monday"
monday_trips.head()

# %%
for i in monday_trips:
    df = stop_times[stop_times['trip_id'] == i]
    df = add_arrival_date(df, dates = arbitrary_dates)
    df = add_departure_date(df, dates = arbitrary_dates)
    
    df['arrival_datetime'] = pd.to_datetime(df['arrival_date'] + ' ' + df['arrival_time'])
    df['departure_datetime'] = pd.to_datetime(df['departure_date'] + ' ' + df['departure_time'])


    # join df with stops
    df = pd.merge(df, stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']],left_on='stop_id', right_on='stop_id')

    # join df with trips to get direction id
    df = pd.merge(df, trips[['trip_id', 'direction_id', 'route_id']], left_on='trip_id', right_on='trip_id', how='left')

    # join df with routes to get route id
    df = pd.merge(df, routes[['route_id', 'route_long_name']], left_on='route_id', right_on='route_id', how='left')

    # make a new dataframe called legs
    legs = pd.DataFrame()
    legs['starttime'] = df['departure_datetime']
    legs['stoptime'] = df['arrival_datetime'].shift(-1).fillna(method='ffill')
    legs['tripduration'] = (legs['stoptime'] - legs['starttime'])/np.timedelta64(1, 's')
    legs['tripduration'] = [int(x) for x in legs['tripduration']]
    legs['start station id'] = df['stop_id']
    legs['start station name'] = df['stop_name']
    legs['start station latitude'] = df['stop_lat']
    legs['start station longitude'] = df['stop_lon']
    legs['end station id'] = legs['start station id'].shift(-1).fillna(method='ffill')
    legs['end station name'] = legs['start station name'].shift(-1).fillna(method='ffill')
    legs['end station latitude'] = legs['start station latitude'].shift(-1).fillna(method='ffill')
    legs['end station longitude'] = legs['start station longitude'].shift(-1).fillna(method='ffill')
    legs['route_id'] = 1 # arbitrary
    legs['direction'] = df['direction_id']
    legs['trainName'] = df['route_long_name']

    triplist.append(legs)

# %%
triplist[1]

# %%
data = pd.concat(triplist)

# %%
len(data)

# %%
data.head(2)

# %%
data.tail(2)

# %%
data.to_csv('queens_monday.csv')

# %% [markdown]
# # Manhattan

# %% [markdown]
# ### Load GTFS data

# %%
agency = pd.read_csv('gtfs/manhattan/agency.txt')
calendar_dates = pd.read_csv('gtfs/manhattan/calendar_dates.txt')
calendar = pd.read_csv('gtfs/manhattan/calendar.txt')
routes = pd.read_csv('gtfs/manhattan/routes.txt')
shapes = pd.read_csv('gtfs/manhattan/shapes.txt')
stop_times = pd.read_csv('gtfs/manhattan/stop_times.txt')
stops = pd.read_csv('gtfs/manhattan/stops.txt')
trips = pd.read_csv('gtfs/manhattan/trips.txt')

service_trip_id = pd.merge(calendar[['service_id']],trips[['service_id', 'trip_id']])
calendar = pd.merge(calendar,service_trip_id)
arbitrary_dates = ['1/5/2015', '1/6/2015']

monday = calendar[calendar['monday'] == 1]
tuesday = calendar[calendar['tuesday'] == 1]
wednesday = calendar[calendar['wednesday'] == 1]
thursday = calendar[calendar['thursday'] == 1]
friday = calendar[calendar['friday'] == 1]
saturday = calendar[calendar['saturday'] == 1]
sunday = calendar[calendar['sunday'] == 1]

triplist = []

monday_trips = monday['trip_id']
print "There are ", len(monday_trips), "trips on Monday"
monday_trips.head()

# %% [markdown]
# ### Monday

# %%
for i in monday_trips:
    df = stop_times[stop_times['trip_id'] == i]
    df = add_arrival_date(df, dates = arbitrary_dates)
    df = add_departure_date(df, dates = arbitrary_dates)
    
    df['arrival_datetime'] = pd.to_datetime(df['arrival_date'] + ' ' + df['arrival_time'])
    df['departure_datetime'] = pd.to_datetime(df['departure_date'] + ' ' + df['departure_time'])


    # join df with stops
    df = pd.merge(df, stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']],left_on='stop_id', right_on='stop_id')

    # join df with trips to get direction id
    df = pd.merge(df, trips[['trip_id', 'direction_id', 'route_id']], left_on='trip_id', right_on='trip_id', how='left')

    # join df with routes to get route id
    df = pd.merge(df, routes[['route_id', 'route_long_name']], left_on='route_id', right_on='route_id', how='left')

    # make a new dataframe called legs
    legs = pd.DataFrame()
    legs['starttime'] = df['departure_datetime']
    legs['stoptime'] = df['arrival_datetime'].shift(-1).fillna(method='ffill')
    legs['tripduration'] = (legs['stoptime'] - legs['starttime'])/np.timedelta64(1, 's')
    legs['tripduration'] = [int(x) for x in legs['tripduration']]
    legs['start station id'] = df['stop_id']
    legs['start station name'] = df['stop_name']
    legs['start station latitude'] = df['stop_lat']
    legs['start station longitude'] = df['stop_lon']
    legs['end station id'] = legs['start station id'].shift(-1).fillna(method='ffill')
    legs['end station name'] = legs['start station name'].shift(-1).fillna(method='ffill')
    legs['end station latitude'] = legs['start station latitude'].shift(-1).fillna(method='ffill')
    legs['end station longitude'] = legs['start station longitude'].shift(-1).fillna(method='ffill')
    legs['route_id'] = 1 # arbitrary
    legs['direction'] = df['direction_id']
    legs['trainName'] = df['route_long_name']

    triplist.append(legs)

# %%
data = pd.concat(triplist)
data.to_csv('manhattan_monday.csv')

# %% [markdown]
# # Bronx

# %% [markdown]
# ### Load GTFS data

# %%
agency = pd.read_csv('gtfs/bronx/agency.txt')
calendar_dates = pd.read_csv('gtfs/bronx/calendar_dates.txt')
calendar = pd.read_csv('gtfs/bronx/calendar.txt')
routes = pd.read_csv('gtfs/bronx/routes.txt')
shapes = pd.read_csv('gtfs/bronx/shapes.txt')
stop_times = pd.read_csv('gtfs/bronx/stop_times.txt')
stops = pd.read_csv('gtfs/bronx/stops.txt')
trips = pd.read_csv('gtfs/bronx/trips.txt')

service_trip_id = pd.merge(calendar[['service_id']],trips[['service_id', 'trip_id']])
calendar = pd.merge(calendar,service_trip_id)
arbitrary_dates = ['1/5/2015', '1/6/2015']

monday = calendar[calendar['monday'] == 1]
tuesday = calendar[calendar['tuesday'] == 1]
wednesday = calendar[calendar['wednesday'] == 1]
thursday = calendar[calendar['thursday'] == 1]
friday = calendar[calendar['friday'] == 1]
saturday = calendar[calendar['saturday'] == 1]
sunday = calendar[calendar['sunday'] == 1]

triplist = []

monday_trips = monday['trip_id']
print "There are ", len(monday_trips), "trips on Monday"
monday_trips.head()

# %% [markdown]
# ### Monday

# %%
for i in monday_trips:
    df = stop_times[stop_times['trip_id'] == i]
    df = add_arrival_date(df, dates = arbitrary_dates)
    df = add_departure_date(df, dates = arbitrary_dates)
    
    df['arrival_datetime'] = pd.to_datetime(df['arrival_date'] + ' ' + df['arrival_time'])
    df['departure_datetime'] = pd.to_datetime(df['departure_date'] + ' ' + df['departure_time'])


    # join df with stops
    df = pd.merge(df, stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']],left_on='stop_id', right_on='stop_id')

    # join df with trips to get direction id
    df = pd.merge(df, trips[['trip_id', 'direction_id', 'route_id']], left_on='trip_id', right_on='trip_id', how='left')

    # join df with routes to get route id
    df = pd.merge(df, routes[['route_id', 'route_long_name']], left_on='route_id', right_on='route_id', how='left')

    # make a new dataframe called legs
    legs = pd.DataFrame()
    legs['starttime'] = df['departure_datetime']
    legs['stoptime'] = df['arrival_datetime'].shift(-1).fillna(method='ffill')
    legs['tripduration'] = (legs['stoptime'] - legs['starttime'])/np.timedelta64(1, 's')
    legs['tripduration'] = [int(x) for x in legs['tripduration']]
    legs['start station id'] = df['stop_id']
    legs['start station name'] = df['stop_name']
    legs['start station latitude'] = df['stop_lat']
    legs['start station longitude'] = df['stop_lon']
    legs['end station id'] = legs['start station id'].shift(-1).fillna(method='ffill')
    legs['end station name'] = legs['start station name'].shift(-1).fillna(method='ffill')
    legs['end station latitude'] = legs['start station latitude'].shift(-1).fillna(method='ffill')
    legs['end station longitude'] = legs['start station longitude'].shift(-1).fillna(method='ffill')
    legs['route_id'] = 1 # arbitrary
    legs['direction'] = df['direction_id']
    legs['trainName'] = df['route_long_name']

    triplist.append(legs)

# %%
data = pd.concat(triplist)
data.to_csv('bronx_monday.csv')

# %% [markdown]
# # Staten Island

# %% [markdown]
# ### Load GTFS data

# %%
agency = pd.read_csv('gtfs/staten_island/agency.txt')
calendar_dates = pd.read_csv('gtfs/staten_island/calendar_dates.txt')
calendar = pd.read_csv('gtfs/staten_island/calendar.txt')
routes = pd.read_csv('gtfs/staten_island/routes.txt')
shapes = pd.read_csv('gtfs/staten_island/shapes.txt')
stop_times = pd.read_csv('gtfs/staten_island/stop_times.txt')
stops = pd.read_csv('gtfs/staten_island/stops.txt')
trips = pd.read_csv('gtfs/staten_island/trips.txt')

service_trip_id = pd.merge(calendar[['service_id']],trips[['service_id', 'trip_id']])
calendar = pd.merge(calendar,service_trip_id)
arbitrary_dates = ['1/5/2015', '1/6/2015']

monday = calendar[calendar['monday'] == 1]
tuesday = calendar[calendar['tuesday'] == 1]
wednesday = calendar[calendar['wednesday'] == 1]
thursday = calendar[calendar['thursday'] == 1]
friday = calendar[calendar['friday'] == 1]
saturday = calendar[calendar['saturday'] == 1]
sunday = calendar[calendar['sunday'] == 1]

triplist = []

monday_trips = monday['trip_id']
print "There are ", len(monday_trips), "trips on Monday"
monday_trips.head()

# %% [markdown]
# ### Monday

# %%
for i in monday_trips:
    df = stop_times[stop_times['trip_id'] == i]
    df = add_arrival_date(df, dates = arbitrary_dates)
    df = add_departure_date(df, dates = arbitrary_dates)
    
    df['arrival_datetime'] = pd.to_datetime(df['arrival_date'] + ' ' + df['arrival_time'])
    df['departure_datetime'] = pd.to_datetime(df['departure_date'] + ' ' + df['departure_time'])


    # join df with stops
    df = pd.merge(df, stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']],left_on='stop_id', right_on='stop_id')

    # join df with trips to get direction id
    df = pd.merge(df, trips[['trip_id', 'direction_id', 'route_id']], left_on='trip_id', right_on='trip_id', how='left')

    # join df with routes to get route id
    df = pd.merge(df, routes[['route_id', 'route_long_name']], left_on='route_id', right_on='route_id', how='left')

    # make a new dataframe called legs
    legs = pd.DataFrame()
    legs['starttime'] = df['departure_datetime']
    legs['stoptime'] = df['arrival_datetime'].shift(-1).fillna(method='ffill')
    legs['tripduration'] = (legs['stoptime'] - legs['starttime'])/np.timedelta64(1, 's')
    legs['tripduration'] = [int(x) for x in legs['tripduration']]
    legs['start station id'] = df['stop_id']
    legs['start station name'] = df['stop_name']
    legs['start station latitude'] = df['stop_lat']
    legs['start station longitude'] = df['stop_lon']
    legs['end station id'] = legs['start station id'].shift(-1).fillna(method='ffill')
    legs['end station name'] = legs['start station name'].shift(-1).fillna(method='ffill')
    legs['end station latitude'] = legs['start station latitude'].shift(-1).fillna(method='ffill')
    legs['end station longitude'] = legs['start station longitude'].shift(-1).fillna(method='ffill')
    legs['route_id'] = 1 # arbitrary
    legs['direction'] = df['direction_id']
    legs['trainName'] = df['route_long_name']

    triplist.append(legs)

# %%
data = pd.concat(triplist)
data.to_csv('staten_island_monday.csv')
